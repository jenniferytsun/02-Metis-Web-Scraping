# %%
import pandas as pd
import numpy as np

# %%
new = pd.read_pickle('country_pic')

# %%
new = new.fillna(value=np.nan)

# %%
new[1:20]
# Out:
#                      Consumption-based CO2 emissions  \
# Country
# Afghanistan                                      NaN
# Angola                                           NaN
# Anguilla                                         NaN
# Albania                        5.65 million t (2017)
# Andorra                                          NaN
# United Arab Emirates         235.48 million t (2017)
# Argentina                    201.72 million t (2017)
# Armenia                        5.55 million t (2017)
# American Samoa                                   NaN
# Antigua and Barbuda                              NaN
# Australia                    378.34 million t (2017)
# Austria                       94.59 million t (2017)
# Azerbaijan                     40.4 million t (2017)
# Burundi                                          NaN
# Belgium                      178.09 million t (2017)
# Benin                          8.17 million t (2017)
# ...

# %%
#samp
df['DataFrame Column'] = df['DataFrame Column'].astype(float)
df = df.astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6e6cbfef8dc8> in <module>
#       1 #samp
# ----> 2 df['DataFrame Column'] = df['DataFrame Column'].astype(float)
#       3 df = df.astype(float)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Clean data frame, remove all special signs

# %%
def data_processing_dol(source):
    source = source.str.lstrip("$")
    return source

# %%
def data_processing_pc(source):
    source = source.str.rstrip("%")
    return source

# %%
def data_processing(source):
    source = source.str.split(" ", 1, expand=True)
    return source

# %%
#remove all $
new['GDP per capita'] = data_processing_dol(new['GDP per capita'])
new['Fossil-fuel subsidies per capita'] = data_processing_dol(new['Fossil-fuel subsidies per capita'])
new['Direct disaster economic loss'] = data_processing_dol(new['Direct disaster economic loss'])

# %%
#remove %
new['Unemployment rate'] = data_processing_pc(new['Unemployment rate'])
new['Share of the population living in urban areas'] = data_processing_pc(new['Share of the population living in urban areas'])
new['Share of the population using the Internet'] = data_processing_pc(new['Share of the population using the Internet'])
new['Share of migrants among the population'] = data_processing_pc(new['Share of migrants among the population'])
new['Share of land area used for agriculture'] = data_processing_pc(new['Share of land area used for agriculture'])
new['Forest area (% of land area)'] = data_processing_pc(new['Forest area (% of land area)'])
new['Share of important terrerstrial biodiversity sites that are protected'] = data_processing_pc(new['Share of important terrerstrial biodiversity sites that are protected'])

# %%
#remove after
new['Consumption-based CO2 emissions'] = data_processing(new['Consumption-based CO2 emissions'])
new['Annual greenhouse gas emissions'] = data_processing(new['Annual greenhouse gas emissions'])
new['Population density'] = data_processing(new['Population density'])
new['Population (Gapminder & UN (1800 to 2019))'] = data_processing(new['Population (Gapminder & UN (1800 to 2019))'])
new['GDP per capita'] = data_processing(new['GDP per capita'])
new['Life expectancy'] = data_processing(new['Life expectancy'])
new['Female employment-to-population ratio'] = data_processing(new['Female employment-to-population ratio'])
new['Unemployment rate'] = data_processing(new['Unemployment rate'])
new['Daily supply of calories'] = data_processing(new['Daily supply of calories'])
new['Share of the population living in urban areas'] = data_processing(new['Share of the population living in urban areas'])
new['Share of the population using the Internet'] = data_processing(new['Share of the population using the Internet'])
new['Share of migrants among the population'] = data_processing(new['Share of migrants among the population'])
new['International tourism: Number of arrivals'] = data_processing(new['International tourism: Number of arrivals'])
new['Beef and buffalo meat consumption per person'] = data_processing(new['Beef and buffalo meat consumption per person'])
new['Beef production'] = data_processing(new['Beef production'])
new['Share of land area used for agriculture'] = data_processing(new['Share of land area used for agriculture'])
new['Forest area (% of land area)'] = data_processing(new['Forest area (% of land area)'])
new['Share of important terrerstrial biodiversity sites that are protected'] = data_processing(new['Share of important terrerstrial biodiversity sites that are protected'])
new['Fossil-fuel subsidies per capita'] = data_processing(new['Fossil-fuel subsidies per capita'])
new['Death rates from air pollution'] = data_processing(new['Death rates from air pollution'])
new['Direct disaster economic loss'] = data_processing(new['Direct disaster economic loss'])
new['Wine consumption per person'] = data_processing(new['Wine consumption per person'])

# %%
#remove %
new['Unemployment rate'] = data_processing_pc(new['Unemployment rate'])
new['Share of the population living in urban areas'] = data_processing_pc(new['Share of the population living in urban areas'])
new['Share of the population using the Internet'] = data_processing_pc(new['Share of the population using the Internet'])
new['Share of migrants among the population'] = data_processing_pc(new['Share of migrants among the population'])
new['Share of land area used for agriculture'] = data_processing_pc(new['Share of land area used for agriculture'])
new['Forest area (% of land area)'] = data_processing_pc(new['Forest area (% of land area)'])
new['Share of important terrerstrial biodiversity sites that are protected'] = data_processing_pc(new['Share of important terrerstrial biodiversity sites that are protected'])
new['Female employment-to-population ratio']= data_processing_pc(new['Female employment-to-population ratio'])

# %%
new
# Out:
#              Consumption-based CO2 emissions Annual greenhouse gas emissions  \
# Country
# Aruba                                    NaN                             NaN
# Afghanistan                              NaN                       18,168.86
# Angola                                   NaN                       41,657.16
# Anguilla                                 NaN                             NaN
# Albania                                 5.65                        8,898.64
# ...                                      ...                             ...
# Samoa                                    NaN                          356.09
# Yemen                                    NaN                       40,924.63
# South Africa                          340.87                             NaN
# Zambia                                  9.66                      320,254.22
# Zimbabwe                               12.53                        72,057.8
#
# ...

# %%
#remove commas
new = new.replace(',','', regex=True)

# %%
new = new.replace('<','', regex=True)

# %%
new['Female employment-to-population ratio']
# Out:
# Country
# Aruba             53.4
# Afghanistan      15.48
# Angola           69.13
# Anguilla           NaN
# Albania          39.15
#                  ...
# Samoa            21.89
# Yemen             4.46
# South Africa     34.42
# Zambia          64.28%
# Zimbabwe         52.35
# Name: Female employment-to-population ratio, Length: 228, dtype: object

# %%
new['Consumption-based CO2 emissions'] = data_processing(new['Consumption-based CO2 emissions'])
new['Annual greenhouse gas emissions'] = data_processing(new['Annual greenhouse gas emissions'])
new['Population density'] = data_processing(new['Population density'])
new['Population (Gapminder & UN (1800 to 2019))'] = data_processing(new['Population (Gapminder & UN (1800 to 2019))'])
new['GDP per capita'] = data_processing(new['GDP per capita'])
new['Life expectancy'] = data_processing(new['Life expectancy'])
new['Female employment-to-population ratio'] = data_processing(new['Female employment-to-population ratio'])
new['Unemployment rate'] = data_processing(new['Unemployment rate'])
new['Daily supply of calories'] = data_processing(new['Daily supply of calories'])
new['Share of the population living in urban areas'] = data_processing(new['Share of the population living in urban areas'])
new['Share of the population using the Internet'] = data_processing(new['Share of the population using the Internet'])
new['Share of migrants among the population'] = data_processing(new['Share of migrants among the population'])
new['International tourism: Number of arrivals'] = data_processing(new['International tourism: Number of arrivals'])
new['Beef and buffalo meat consumption per person'] = data_processing(new['Beef and buffalo meat consumption per person'])
new['Beef production'] = data_processing(new['Beef production'])
new['Share of land area used for agriculture'] = data_processing(new['Share of land area used for agriculture'])
new['Forest area (% of land area)'] = data_processing(new['Forest area (% of land area)'])
new['Share of important terrerstrial biodiversity sites that are protected'] = data_processing(new['Share of important terrerstrial biodiversity sites that are protected'])
new['Fossil-fuel subsidies per capita'] = data_processing(new['Fossil-fuel subsidies per capita'])
new['Death rates from air pollution'] = data_processing(new['Death rates from air pollution'])
new['Direct disaster economic loss'] = data_processing(new['Direct disaster economic loss'])
new['Wine consumption per person'] = data_processing(new['Wine consumption per person'])

# %%
new['Share of the population living in urban areas']
# Out:
# Country
# Aruba           43.55
# Afghanistan     25.75
# Angola          66.18
# Anguilla          100
# Albania         61.23
#                 ...
# Samoa           18.06
# Yemen           37.27
# South Africa    66.86
# Zambia          44.07
# Zimbabwe        32.21
# Name: Share of the population living in urban areas, Length: 228, dtype: object

# %%
# convert to float
new2 = new.astype(float)

# %%
new2
# Out:
#               Consumption-based CO2 emissions  \
# Country
# Aruba                                     NaN
# Afghanistan                               NaN
# Angola                                    NaN
# Anguilla                                  NaN
# Albania                                  5.65
# ...                                       ...
# Samoa                                     NaN
# Yemen                                     NaN
# South Africa                           340.87
# Zambia                                   9.66
# Zimbabwe                                12.53
#
#               Annual greenhouse gas emissions  Population density  \
# Country
# Aruba                                     NaN              619.64
# Afghanistan                          18168.86               53.69
# Angola                               41657.16               17.33
# Anguilla                                  NaN              135.32
# ...

# %%
new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 228 entries, Aruba to Zimbabwe
# Data columns (total 22 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Consumption-based CO2 emissions                                        119 non-null    float64
#  1   Annual greenhouse gas emissions                                        179 non-null    float64
#  2   Population density                                                     222 non-null    float64
#  3   Population (Gapminder & UN (1800 to 2019))                             223 non-null    float64
#  4   GDP per capita                                                         166 non-null    float64
#  5   Life expectancy                                                        223 non-null    float64
# ...

# %%
filename = 'country_pic_2'
outfile = open(filename,'wb')

# %%
pickle.dump(new2,outfile)
outfile.close()
