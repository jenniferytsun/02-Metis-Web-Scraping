# %%
from bs4 import BeautifulSoup
import requests
import time, os
import pandas as pd
import pandas as pd


from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ## Set up Soup

# %%
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
base_url = 'https://ourworldindata.org/countries'
driver = webdriver.Chrome(chromedriver)
driver.get(base_url)
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
main = soup.find('main')
rows = [row for row in main.find_all('li')]
country_paths = [x.findChildren()[1]['href'] for x in rows]

# %% [markdown]
# ## Get all country links

# %%
all_country_links=[]
for x in country_paths:
    base2=base_url.replace('/countries', '')
    country_url = (base2+x)
    all_country_links.append(country_url)

# %% [markdown]
# ## Get all indicators

# %%
def get_indicators(soup, field_name):
    obj = soup.find(text=field_name)
    if not obj: 
        return None
    
    next_element = obj.findNext()
    if next_element:
        return next_element.text 
    else:
        return None

# %% [markdown]
# ## Get indicators function

# %%
def get_indicators_dict(link):
    '''
    From world data link stub, request country html, parse with BeautifulSoup, and
    collect 
        - pop density
        - gdp
    Return information as a dictionary.
    '''
  
    #request html and parse
    driver2 = webdriver.Chrome(chromedriver)
    driver2.get(link)
    soup = BeautifulSoup(driver2.page_source, 'html.parser')
    
    headers=['Country','Consumption-based CO2 emissions', 'Annual greenhouse gas emissions', 'Population density', 'Population (Gapminder & UN (1800 to 2019))', 'GDP per capita', 'Life expectancy', 'Female employment-to-population ratio', 'Unemployment rate', 'Daily supply of calories', 'Share of the population living in urban areas', 'Share of the population using the Internet', 'Share of migrants among the population', 'International tourism: Number of arrivals', 'Beef and buffalo meat consumption per person', 'Beef production', 'Share of land area used for agriculture', 'Forest area (% of land area)', 'Share of important terrerstrial biodiversity sites that are protected', 'Fossil-fuel subsidies per capita', 'Death rates from air pollution', 'Direct disaster economic loss', 'Wine consumption per person']
    
    #get country name
    country_name = soup.find('img', class_ ="flag").findNext().text
    
    #get indicators
 
    raw_consumption_based_co2 = get_indicators(soup, 'Consumption-based CO2 emissions')
    
    raw_annual_ggas = get_indicators(soup,'Annual greenhouse gas emissions')
    
    raw_pop_den = get_indicators(soup,'Population density')
    
    raw_pop = get_indicators(soup,'Population (Gapminder & UN (1800 to 2019))')
    
    raw_gdp_percap = get_indicators(soup,'GDP per capita')
    
    raw_life = get_indicators(soup,'Life expectancy')
    
    raw_f_employ = get_indicators(soup,'Female employment-to-population ratio')
    
    raw_unemploy = get_indicators(soup,'Unemployment rate')
    
    raw_daily_cal = get_indicators(soup,'Daily supply of calories')
    
    raw_share_pop_urban = get_indicators(soup,'Share of the population living in urban areas')
    
    raw_share_pop_int = get_indicators(soup,'Share of the population using the Internet')
    
    raw_share_mig_pop = get_indicators(soup,'Share of migrants among the population')
    
    raw_intern_tourism = get_indicators(soup,'International tourism: Number of arrivals')
    
    raw_beef_consum_pp = get_indicators(soup,'Beef and buffalo meat consumption per person')
    
    raw_beef_prod = get_indicators(soup,'Beef production')
    
    raw_share_land_agr = get_indicators(soup,'Share of land area used for agriculture')
    
    raw_forest_pc = get_indicators(soup,'Forest area (% of land area)')
    
    raw_share_sites_protect = get_indicators(soup,'Share of important terrerstrial biodiversity sites that are protected')
    
    raw_fossfuel_subs = get_indicators(soup,'Fossil-fuel subsidies per capita')
    
    raw_death_rate_air_poll = get_indicators(soup,'Death rates from air pollution')
    
    raw_disaster_econ_loss = get_indicators(soup,'Direct disaster economic loss')

    raw_wine_consum_pp = get_indicators(soup,'Wine consumption per person')


    world_data=[]
    
    #create country dictionary and return
    world_dict = dict(zip(headers, [country_name, raw_consumption_based_co2, raw_annual_ggas, raw_pop_den, raw_pop, raw_gdp_percap, raw_life, raw_f_employ, raw_unemploy, raw_daily_cal, raw_share_pop_urban, raw_share_pop_int, raw_share_mig_pop, raw_intern_tourism, raw_beef_consum_pp, raw_beef_prod, raw_share_land_agr, raw_forest_pc, raw_share_sites_protect, raw_fossfuel_subs, raw_death_rate_air_poll, raw_disaster_econ_loss, raw_wine_consum_pp]))
    return world_dict

# %% [markdown]
# ## Create list of all indicators

# %%
country_info_list = []

for link in all_country_links:
    country_info_list.append(get_indicators_dict(link))

# %%
country_info_list
# Out:
# [{'Country': 'Aruba',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': None,
#   'Population density': '619.64 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '106,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '76.3 years (2019)',
#   'Female employment-to-population ratio': '53.4 (2011)',
#   'Unemployment rate': None,
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '43.55% (2019)',
#   'Share of the population using the Internet': '93.54% (2016)',
#   'Share of migrants among the population': '34.76% (2015)',
#   'International tourism: Number of arrivals': '1.1 million (2016)',
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': None,
#   'Share of land area used for agriculture': '11.11% (2015)',
#   'Forest area (% of land area)': '2.33% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '31.9% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': None,
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': None},
#  {'Country': 'Afghanistan',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '18,168.86 t (2012)',
#   'Population density': '53.69 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '38.04 million (2019)',
#   'GDP per capita': '$1,929 (2016)',
#   'Life expectancy': '64.8 years (2019)',
#   'Female employment-to-population ratio': '15.48 (2012)',
#   'Unemployment rate': '8.84% (2017)',
#   'Daily supply of calories': '2,000 kcal (2017)',
#   'Share of the population living in urban areas': '25.75% (2019)',
#   'Share of the population using the Internet': '10.6% (2016)',
#   'Share of migrants among the population': '1.18% (2015)',
#   'International tourism: Number of arrivals': None,
#   'Beef and buffalo meat consumption per person': '4.59 (2013)',
#   'Beef production': '129,691 t (2018)',
#   'Share of land area used for agriculture': '58.07% (2015)',
#   'Forest area (% of land area)': '2.07% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '6.14% (2018)',
#   'Fossil-fuel subsidies per capita': '$0.83 (2015)',
#   'Death rates from air pollution': '183.9 (2017)',
#   'Direct disaster economic loss': '$52.18 million (2017)',
#   'Wine consumption per person': '0 litres (2013)'},
#  {'Country': 'Angola',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '41,657.16 t (2012)',
#   'Population density': '17.33 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '31.82 million (2019)',
#   'GDP per capita': '$8,397 (2016)',
#   'Life expectancy': '61.1 years (2019)',
#   'Female employment-to-population ratio': '69.13 (2011)',
#   'Unemployment rate': '8.17% (2017)',
#   'Daily supply of calories': '2,270 kcal (2017)',
#   'Share of the population living in urban areas': '66.18% (2019)',
#   'Share of the population using the Internet': '13% (2016)',
#   'Share of migrants among the population': '0.43% (2015)',
#   'International tourism: Number of arrivals': '397,000 (2016)',
#   'Beef and buffalo meat consumption per person': '8.42 (2013)',
#   'Beef production': '104,761 t (2018)',
#   'Share of land area used for agriculture': '47.48% (2015)',
#   'Forest area (% of land area)': '46.41% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '28.37% (2018)',
#   'Fossil-fuel subsidies per capita': '$38.37 (2015)',
#   'Death rates from air pollution': '95.2 (2017)',
#   'Direct disaster economic loss': '$69.24 million (2018)',
#   'Wine consumption per person': '1.32 litres (2014)'},
#  {'Country': 'Anguilla',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': None,
#   'Population density': '135.32 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '15,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '81.9 years (2019)',
#   'Female employment-to-population ratio': None,
#   'Unemployment rate': None,
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '100% (2019)',
#   'Share of the population using the Internet': None,
#   'Share of migrants among the population': None,
#   'International tourism: Number of arrivals': None,
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': None,
#   'Share of land area used for agriculture': None,
#   'Forest area (% of land area)': None,
#   'Share of important terrerstrial biodiversity sites that are protected': '0.15% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': None,
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': None},
#  {'Country': 'Albania',
#   'Consumption-based CO2 emissions': '5.65 million t (2017)',
#   'Annual greenhouse gas emissions': '8,898.64 t (2012)',
#   'Population density': '114.91 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '2.88 million (2019)',
#   'GDP per capita': '$11,285 (2016)',
#   'Life expectancy': '78.6 years (2019)',
#   'Female employment-to-population ratio': '39.15 (2015)',
#   'Unemployment rate': '13.87% (2017)',
#   'Daily supply of calories': '3,400 kcal (2017)',
#   'Share of the population living in urban areas': '61.23% (2019)',
#   'Share of the population using the Internet': '66.36% (2016)',
#   'Share of migrants among the population': '1.99% (2015)',
#   'International tourism: Number of arrivals': '4.07 million (2016)',
#   'Beef and buffalo meat consumption per person': '22.5 (2013)',
#   'Beef production': '38,544 t (2018)',
#   'Share of land area used for agriculture': '42.86% (2015)',
#   'Forest area (% of land area)': '28.16% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '76.11% (2018)',
#   'Fossil-fuel subsidies per capita': '$21.74 (2015)',
#   'Death rates from air pollution': '40.5 (2017)',
#   'Direct disaster economic loss': '$5.33 million (2018)',
#   'Wine consumption per person': '1.14 litres (2014)'},
#  {'Country': 'Andorra',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': None,
#   'Population density': '172.41 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '77,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '83.7 years (2019)',
#   'Female employment-to-population ratio': None,
#   'Unemployment rate': None,
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '87.98% (2019)',
#   'Share of the population using the Internet': '97.93% (2016)',
#   'Share of migrants among the population': '59.71% (2015)',
#   'International tourism: Number of arrivals': '2.83 million (2016)',
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': None,
#   'Share of land area used for agriculture': '40.02% (2015)',
#   'Forest area (% of land area)': '34.04% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '26.08% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '15.6 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '4.29 litres (2013)'},
#  {'Country': 'United Arab Emirates',
#   'Consumption-based CO2 emissions': '235.48 million t (2017)',
#   'Annual greenhouse gas emissions': '204,888.72 t (2012)',
#   'Population density': '67.9 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '9.77 million (2019)',
#   'GDP per capita': '$70,284 (2016)',
#   'Life expectancy': '78 years (2019)',
#   'Female employment-to-population ratio': '49.05 (2017)',
#   'Unemployment rate': '1.67% (2017)',
#   'Daily supply of calories': '3,366 kcal (2017)',
#   'Share of the population living in urban areas': '86.79% (2019)',
#   'Share of the population using the Internet': '94.82% (2017)',
#   'Share of migrants among the population': '88.4% (2015)',
#   'International tourism: Number of arrivals': None,
#   'Beef and buffalo meat consumption per person': '5.64 (2013)',
#   'Beef production': '19,917 t (2018)',
#   'Share of land area used for agriculture': '4.57% (2015)',
#   'Forest area (% of land area)': '3.86% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '57.9% (2018)',
#   'Fossil-fuel subsidies per capita': '$1,319.65 (2015)',
#   'Death rates from air pollution': '77.8 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.13 litres (2014)'},
#  {'Country': 'Argentina',
#   'Consumption-based CO2 emissions': '201.72 million t (2017)',
#   'Annual greenhouse gas emissions': '380,295.32 t (2012)',
#   'Population density': '15.4 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '44.78 million (2019)',
#   'GDP per capita': '$18,695 (2016)',
#   'Life expectancy': '76.7 years (2019)',
#   'Female employment-to-population ratio': '43.47 (2017)',
#   'Unemployment rate': '8.52% (2017)',
#   'Daily supply of calories': '3,239 kcal (2017)',
#   'Share of the population living in urban areas': '91.99% (2019)',
#   'Share of the population using the Internet': '70.97% (2016)',
#   'Share of migrants among the population': '4.81% (2015)',
#   'International tourism: Number of arrivals': '5.56 million (2016)',
#   'Beef and buffalo meat consumption per person': '55.48 (2013)',
#   'Beef production': '3.07 million t (2018)',
#   'Share of land area used for agriculture': '54.34% (2015)',
#   'Forest area (% of land area)': '9.91% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '32.4% (2018)',
#   'Fossil-fuel subsidies per capita': '$206.54 (2015)',
#   'Death rates from air pollution': '31.1 (2017)',
#   'Direct disaster economic loss': '$240.18 million (2017)',
#   'Wine consumption per person': '3.22 litres (2014)'},
#  {'Country': 'Armenia',
#   'Consumption-based CO2 emissions': '5.55 million t (2017)',
#   'Annual greenhouse gas emissions': '12,319.39 t (2012)',
#   'Population density': '109.49 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '2.96 million (2019)',
#   'GDP per capita': '$9,588 (2016)',
#   'Life expectancy': '75.1 years (2019)',
#   'Female employment-to-population ratio': '43.59 (2017)',
#   'Unemployment rate': '18.23% (2017)',
#   'Daily supply of calories': '3,078 kcal (2017)',
#   'Share of the population living in urban areas': '63.22% (2019)',
#   'Share of the population using the Internet': '64.35% (2016)',
#   'Share of migrants among the population': '6.34% (2015)',
#   'International tourism: Number of arrivals': '1.26 million (2016)',
#   'Beef and buffalo meat consumption per person': '19.66 (2013)',
#   'Beef production': '68,800 t (2018)',
#   'Share of land area used for agriculture': '58.88% (2015)',
#   'Forest area (% of land area)': '11.66% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '21.55% (2018)',
#   'Fossil-fuel subsidies per capita': '$1.4 (2015)',
#   'Death rates from air pollution': '64.8 (2017)',
#   'Direct disaster economic loss': '$13.36 million (2017)',
#   'Wine consumption per person': '0.13 litres (2014)'},
#  {'Country': 'American Samoa',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '58.77 t (2012)',
#   'Population density': '578.38 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '55,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '73.7 years (2019)',
#   'Female employment-to-population ratio': None,
#   'Unemployment rate': None,
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '87.15% (2019)',
#   'Share of the population using the Internet': None,
#   'Share of migrants among the population': '41.8% (2015)',
#   'International tourism: Number of arrivals': '20,100 (2016)',
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': '4 t (2018)',
#   'Share of land area used for agriculture': '24.5% (2015)',
#   'Forest area (% of land area)': '87.7% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '61.49% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '58.9 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': None},
#  {'Country': 'Antigua and Barbuda',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '552.75 t (2012)',
#   'Population density': '222.49 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '97,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '77 years (2019)',
#   'Female employment-to-population ratio': None,
#   'Unemployment rate': None,
#   'Daily supply of calories': '2,430 kcal (2017)',
#   'Share of the population living in urban areas': '24.51% (2019)',
#   'Share of the population using the Internet': '73% (2016)',
#   'Share of migrants among the population': '30.59% (2015)',
#   'International tourism: Number of arrivals': '265,000 (2016)',
#   'Beef and buffalo meat consumption per person': '12.42 (2013)',
#   'Beef production': '168 t (2018)',
#   'Share of land area used for agriculture': '20.45% (2015)',
#   'Forest area (% of land area)': '22.27% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '14.87% (2018)',
#   'Fossil-fuel subsidies per capita': '$111.43 (2015)',
#   'Death rates from air pollution': '32.4 (2017)',
#   'Direct disaster economic loss': '$334,776.64 (2014)',
#   'Wine consumption per person': '1.87 litres (2014)'},
#  {'Country': 'Australia',
#   'Consumption-based CO2 emissions': '378.34 million t (2017)',
#   'Annual greenhouse gas emissions': '761,686.27 t (2012)',
#   'Population density': '2.94 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '25.2 million (2019)',
#   'GDP per capita': '$44,783 (2016)',
#   'Life expectancy': '83.4 years (2019)',
#   'Female employment-to-population ratio': '56.46 (2017)',
#   'Unemployment rate': '5.59% (2017)',
#   'Daily supply of calories': '3,311 kcal (2017)',
#   'Share of the population living in urban areas': '86.12% (2019)',
#   'Share of the population using the Internet': '86.54% (2017)',
#   'Share of migrants among the population': '28.22% (2015)',
#   'International tourism: Number of arrivals': '8.26 million (2016)',
#   'Beef and buffalo meat consumption per person': '33.86 (2013)',
#   'Beef production': '2.22 million t (2018)',
#   'Share of land area used for agriculture': '47.63% (2015)',
#   'Forest area (% of land area)': '16.24% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '52.67% (2018)',
#   'Fossil-fuel subsidies per capita': '$34.28 (2015)',
#   'Death rates from air pollution': '10.8 (2017)',
#   'Direct disaster economic loss': '$169.9 million (2018)',
#   'Wine consumption per person': '3.64 litres (2014)'},
#  {'Country': 'Austria',
#   'Consumption-based CO2 emissions': '94.59 million t (2017)',
#   'Annual greenhouse gas emissions': '90,460.21 t (2012)',
#   'Population density': '102.39 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '8.96 million (2019)',
#   'GDP per capita': '$45,010 (2016)',
#   'Life expectancy': '81.5 years (2019)',
#   'Female employment-to-population ratio': '53.1 (2017)',
#   'Unemployment rate': '5.5% (2017)',
#   'Daily supply of calories': '3,692 kcal (2017)',
#   'Share of the population living in urban areas': '58.52% (2019)',
#   'Share of the population using the Internet': '87.94% (2017)',
#   'Share of migrants among the population': '17.47% (2015)',
#   'International tourism: Number of arrivals': '28.12 million (2016)',
#   'Beef and buffalo meat consumption per person': '17.14 (2013)',
#   'Beef production': '233,723 t (2018)',
#   'Share of land area used for agriculture': '32.94% (2015)',
#   'Forest area (% of land area)': '46.88% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '66.63% (2018)',
#   'Fossil-fuel subsidies per capita': '$16.29 (2015)',
#   'Death rates from air pollution': '17.6 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '4.37 litres (2014)'},
#  {'Country': 'Azerbaijan',
#   'Consumption-based CO2 emissions': '40.4 million t (2017)',
#   'Annual greenhouse gas emissions': '56,537.08 t (2012)',
#   'Population density': '109.46 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '10.05 million (2019)',
#   'GDP per capita': '$15,296 (2016)',
#   'Life expectancy': '73 years (2019)',
#   'Female employment-to-population ratio': '59.2 (2017)',
#   'Unemployment rate': '5.03% (2017)',
#   'Daily supply of calories': '3,103 kcal (2017)',
#   'Share of the population living in urban areas': '56.03% (2019)',
#   'Share of the population using the Internet': '79% (2017)',
#   'Share of migrants among the population': '2.71% (2015)',
#   'International tourism: Number of arrivals': '2.04 million (2016)',
#   'Beef and buffalo meat consumption per person': '12.68 (2013)',
#   'Beef production': '135,620 t (2018)',
#   'Share of land area used for agriculture': '57.7% (2015)',
#   'Forest area (% of land area)': '13.78% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '38.16% (2018)',
#   'Fossil-fuel subsidies per capita': '$92.9 (2015)',
#   'Death rates from air pollution': '80.2 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.23 litres (2013)'},
#  {'Country': 'Burundi',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '6,254.37 t (2012)',
#   'Population density': '381.04 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '11.53 million (2019)',
#   'GDP per capita': '$692 (2016)',
#   'Life expectancy': '61.6 years (2019)',
#   'Female employment-to-population ratio': '78.92 (2017)',
#   'Unemployment rate': '1.55% (2017)',
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '13.37% (2019)',
#   'Share of the population using the Internet': '5.17% (2016)',
#   'Share of migrants among the population': '2.57% (2015)',
#   'International tourism: Number of arrivals': '187,000 (2016)',
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': '10,301 t (2018)',
#   'Share of land area used for agriculture': '79.13% (2015)',
#   'Forest area (% of land area)': '10.75% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '67.32% (2018)',
#   'Fossil-fuel subsidies per capita': '$0 (2013)',
#   'Death rates from air pollution': '142.8 (2017)',
#   'Direct disaster economic loss': '$21.38 million (2017)',
#   'Wine consumption per person': '0 litres (2011)'},
#  {'Country': 'Belgium',
#   'Consumption-based CO2 emissions': '178.09 million t (2017)',
#   'Annual greenhouse gas emissions': '133,373.68 t (2012)',
#   'Population density': '356.38 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '11.54 million (2019)',
#   'GDP per capita': '$39,733 (2016)',
#   'Life expectancy': '81.6 years (2019)',
#   'Female employment-to-population ratio': '45.28 (2017)',
#   'Unemployment rate': '7.09% (2017)',
#   'Daily supply of calories': '3,768 kcal (2017)',
#   'Share of the population living in urban areas': '98.04% (2019)',
#   'Share of the population using the Internet': '87.68% (2017)',
#   'Share of migrants among the population': '12.28% (2015)',
#   'International tourism: Number of arrivals': '7.48 million (2016)',
#   'Beef and buffalo meat consumption per person': '15.63 (2013)',
#   'Beef production': '277,311 t (2018)',
#   'Share of land area used for agriculture': '43.86% (2015)',
#   'Forest area (% of land area)': '22.57% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '81% (2018)',
#   'Fossil-fuel subsidies per capita': '$270.04 (2015)',
#   'Death rates from air pollution': '19.1 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '4.53 litres (2014)'},
#  {'Country': 'Benin',
#   'Consumption-based CO2 emissions': '8.17 million t (2017)',
#   'Annual greenhouse gas emissions': '33,533.1 t (2012)',
#   'Population density': '92.43 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '11.8 million (2019)',
#   'GDP per capita': '$2,166 (2016)',
#   'Life expectancy': '61.8 years (2019)',
#   'Female employment-to-population ratio': '67.71 (2011)',
#   'Unemployment rate': '2.47% (2017)',
#   'Daily supply of calories': '2,756 kcal (2017)',
#   'Share of the population living in urban areas': '47.86% (2019)',
#   'Share of the population using the Internet': '11.99% (2016)',
#   'Share of migrants among the population': '2.26% (2015)',
#   'International tourism: Number of arrivals': '267,000 (2016)',
#   'Beef and buffalo meat consumption per person': '3.05 (2013)',
#   'Beef production': '41,854 t (2018)',
#   'Share of land area used for agriculture': '33.26% (2015)',
#   'Forest area (% of land area)': '38.23% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '77.38% (2018)',
#   'Fossil-fuel subsidies per capita': '$0 (2015)',
#   'Death rates from air pollution': '113.2 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.22 litres (2011)'},
#  {'Country': 'Burkina Faso',
#   'Consumption-based CO2 emissions': '4.97 million t (2017)',
#   'Annual greenhouse gas emissions': '43,910.4 t (2012)',
#   'Population density': '68.96 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '20.32 million (2019)',
#   'GDP per capita': '$1,561 (2016)',
#   'Life expectancy': '61.6 years (2019)',
#   'Female employment-to-population ratio': '52.89 (2014)',
#   'Unemployment rate': '6.3% (2017)',
#   'Daily supply of calories': '2,720 kcal (2017)',
#   'Share of the population living in urban areas': '29.98% (2019)',
#   'Share of the population using the Internet': '13.96% (2016)',
#   'Share of migrants among the population': '3.89% (2015)',
#   'International tourism: Number of arrivals': '152,000 (2016)',
#   'Beef and buffalo meat consumption per person': '4.48 (2013)',
#   'Beef production': '110,130 t (2018)',
#   'Share of land area used for agriculture': '44.23% (2015)',
#   'Forest area (% of land area)': '19.55% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '71.83% (2018)',
#   'Fossil-fuel subsidies per capita': '$7.57 (2015)',
#   'Death rates from air pollution': '133.2 (2017)',
#   'Direct disaster economic loss': '$72.32 million (2015)',
#   'Wine consumption per person': '0.1 litres (2013)'},
#  {'Country': 'Bangladesh',
#   'Consumption-based CO2 emissions': '102.79 million t (2017)',
#   'Annual greenhouse gas emissions': '183,300.56 t (2012)',
#   'Population density': '1,271.22 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '163.05 million (2019)',
#   'GDP per capita': '$3,250 (2016)',
#   'Life expectancy': '72.6 years (2019)',
#   'Female employment-to-population ratio': '33.92 (2017)',
#   'Unemployment rate': '4.37% (2017)',
#   'Daily supply of calories': '2,596 kcal (2017)',
#   'Share of the population living in urban areas': '37.41% (2019)',
#   'Share of the population using the Internet': '18.25% (2016)',
#   'Share of migrants among the population': '0.88% (2015)',
#   'International tourism: Number of arrivals': '125,000 (2014)',
#   'Beef and buffalo meat consumption per person': '1.28 (2013)',
#   'Beef production': '205,684 t (2018)',
#   'Share of land area used for agriculture': '70.63% (2015)',
#   'Forest area (% of land area)': '10.98% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '48.02% (2018)',
#   'Fossil-fuel subsidies per capita': '$15.52 (2015)',
#   'Death rates from air pollution': '108.5 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0 litres (2013)'},
#  {'Country': 'Bulgaria',
#   'Consumption-based CO2 emissions': '40.69 million t (2017)',
#   'Annual greenhouse gas emissions': '67,942.7 t (2012)',
#   'Population density': '65.87 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '7 million (2019)',
#   'GDP per capita': '$17,953 (2016)',
#   'Life expectancy': '75 years (2019)',
#   'Female employment-to-population ratio': '46.57 (2017)',
#   'Unemployment rate': '6.16% (2017)',
#   'Daily supply of calories': '2,828 kcal (2017)',
#   'Share of the population living in urban areas': '75.35% (2019)',
#   'Share of the population using the Internet': '63.41% (2017)',
#   'Share of migrants among the population': '1.43% (2015)',
#   'International tourism: Number of arrivals': '8.25 million (2016)',
#   'Beef and buffalo meat consumption per person': '3.84 (2013)',
#   'Beef production': '16,305 t (2018)',
#   'Share of land area used for agriculture': '46.17% (2015)',
#   'Forest area (% of land area)': '35.22% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '98.85% (2018)',
#   'Fossil-fuel subsidies per capita': '$0 (2015)',
#   'Death rates from air pollution': '51.4 (2017)',
#   'Direct disaster economic loss': '$41.31 million (2018)',
#   'Wine consumption per person': '2.87 litres (2014)'},
#  {'Country': 'Bahrain',
#   'Consumption-based CO2 emissions': '18.93 million t (2017)',
#   'Annual greenhouse gas emissions': '32,849.11 t (2012)',
#   'Population density': '1,047.31 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '1.64 million (2019)',
#   'GDP per capita': '$39,773 (2016)',
#   'Life expectancy': '77.3 years (2019)',
#   'Female employment-to-population ratio': '42.01 (2015)',
#   'Unemployment rate': '1.2% (2017)',
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '89.39% (2019)',
#   'Share of the population using the Internet': '95.88% (2017)',
#   'Share of migrants among the population': '51.13% (2015)',
#   'International tourism: Number of arrivals': '10.16 million (2016)',
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': '986 t (2018)',
#   'Share of land area used for agriculture': '11.15% (2015)',
#   'Forest area (% of land area)': '0.78% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '27.46% (2018)',
#   'Fossil-fuel subsidies per capita': '$1,326.15 (2015)',
#   'Death rates from air pollution': '62.9 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.13 litres (2014)'},
#  {'Country': 'Bahamas',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '4,865.21 t (2012)',
#   'Population density': '31.72 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '389,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '73.9 years (2019)',
#   'Female employment-to-population ratio': '59.42 (2012)',
#   'Unemployment rate': '12.57% (2017)',
#   'Daily supply of calories': '2,043 kcal (2017)',
#   'Share of the population living in urban areas': '83.13% (2019)',
#   'Share of the population using the Internet': '80% (2016)',
#   'Share of migrants among the population': '15.28% (2015)',
#   'International tourism: Number of arrivals': '1.48 million (2016)',
#   'Beef and buffalo meat consumption per person': '19.92 (2013)',
#   'Beef production': '17 t (2018)',
#   'Share of land area used for agriculture': '1.4% (2015)',
#   'Forest area (% of land area)': '51.45% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '24.15% (2018)',
#   'Fossil-fuel subsidies per capita': '$119.45 (2015)',
#   'Death rates from air pollution': '32.2 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '1.6 litres (2014)'},
#  {'Country': 'Bosnia and Herzegovina',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '27,108.4 t (2012)',
#   'Population density': '72.54 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '3.3 million (2019)',
#   'GDP per capita': '$10,576 (2016)',
#   'Life expectancy': '77.4 years (2019)',
#   'Female employment-to-population ratio': '22.51 (2017)',
#   'Unemployment rate': '25.56% (2017)',
#   'Daily supply of calories': '3,269 kcal (2017)',
#   'Share of the population living in urban areas': '48.63% (2019)',
#   'Share of the population using the Internet': '69.49% (2017)',
#   'Share of migrants among the population': '0.91% (2015)',
#   'International tourism: Number of arrivals': '777,000 (2016)',
#   'Beef and buffalo meat consumption per person': '9.12 (2013)',
#   'Beef production': '11,543 t (2018)',
#   'Share of land area used for agriculture': '42.64% (2015)',
#   'Forest area (% of land area)': '42.68% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '18.18% (2018)',
#   'Fossil-fuel subsidies per capita': '$0 (2015)',
#   'Death rates from air pollution': '58.1 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.15 litres (2014)'},
#  {'Country': 'Saint Barthélemy',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': None,
#   'Population density': None,
#   'Population (Gapminder & UN (1800 to 2019))': None,
#   'GDP per capita': None,
#   'Life expectancy': None,
#   'Female employment-to-population ratio': None,
#   'Unemployment rate': None,
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': None,
#   'Share of the population using the Internet': None,
#   'Share of migrants among the population': None,
#   'International tourism: Number of arrivals': None,
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': None,
#   'Share of land area used for agriculture': None,
#   'Forest area (% of land area)': None,
#   'Share of important terrerstrial biodiversity sites that are protected': None,
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': None,
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': None},
#  {'Country': 'Belarus',
#   'Consumption-based CO2 emissions': '69.46 million t (2017)',
#   'Annual greenhouse gas emissions': '109,647.24 t (2012)',
#   'Population density': '45.75 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '9.45 million (2019)',
#   'GDP per capita': '$18,766 (2016)',
#   'Life expectancy': '74.8 years (2019)',
#   'Female employment-to-population ratio': '64.1 (2016)',
#   'Unemployment rate': '0.48% (2017)',
#   'Daily supply of calories': '3,289 kcal (2017)',
#   'Share of the population living in urban areas': '79.04% (2019)',
#   'Share of the population using the Internet': '74.44% (2017)',
#   'Share of migrants among the population': '11.4% (2015)',
#   'International tourism: Number of arrivals': '9.42 million (2016)',
#   'Beef and buffalo meat consumption per person': '17.11 (2013)',
#   'Beef production': '326,100 t (2018)',
#   'Share of land area used for agriculture': '42.29% (2015)',
#   'Forest area (% of land area)': '42.55% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '48.62% (2018)',
#   'Fossil-fuel subsidies per capita': '$10.52 (2015)',
#   'Death rates from air pollution': '50.7 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.37 litres (2014)'},
#  {'Country': 'Belize',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '1,569.86 t (2012)',
#   'Population density': '15.91 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '390,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '74.6 years (2019)',
#   'Female employment-to-population ratio': '42.88 (2017)',
#   'Unemployment rate': '9.33% (2017)',
#   'Daily supply of calories': '2,698 kcal (2017)',
#   'Share of the population living in urban areas': '45.87% (2019)',
#   'Share of the population using the Internet': '44.58% (2016)',
#   'Share of migrants among the population': '14.99% (2015)',
#   'International tourism: Number of arrivals': '386,000 (2016)',
#   'Beef and buffalo meat consumption per person': '4.86 (2013)',
#   'Beef production': '1,783 t (2018)',
#   'Share of land area used for agriculture': '7.01% (2015)',
#   'Forest area (% of land area)': '59.9% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '45.96% (2018)',
#   'Fossil-fuel subsidies per capita': '$125.32 (2015)',
#   'Death rates from air pollution': '44.2 (2017)',
#   'Direct disaster economic loss': '$64.6 (2011)',
#   'Wine consumption per person': '0.2 litres (2014)'},
#  {'Country': 'Bermuda',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '632.88 t (2012)',
#   'Population density': '1,212.91 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '63,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '82.6 years (2019)',
#   'Female employment-to-population ratio': None,
#   'Unemployment rate': None,
#   'Daily supply of calories': '2,671 kcal (2013)',
#   'Share of the population living in urban areas': '100% (2019)',
#   'Share of the population using the Internet': '98% (2016)',
#   'Share of migrants among the population': '30.85% (2015)',
#   'International tourism: Number of arrivals': '244,000 (2016)',
#   'Beef and buffalo meat consumption per person': '33.15 (2013)',
#   'Beef production': '29 t (2018)',
#   'Share of land area used for agriculture': '6% (2015)',
#   'Forest area (% of land area)': '20% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '51.98% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '17.6 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': None},
#  {'Country': 'Bolivia',
#   'Consumption-based CO2 emissions': '20.2 million t (2017)',
#   'Annual greenhouse gas emissions': '621,726.73 t (2012)',
#   'Population density': '10.03 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '11.51 million (2019)',
#   'GDP per capita': '$6,118 (2016)',
#   'Life expectancy': '71.5 years (2019)',
#   'Female employment-to-population ratio': '54.92 (2017)',
#   'Unemployment rate': '3.15% (2017)',
#   'Daily supply of calories': '2,354 kcal (2017)',
#   'Share of the population living in urban areas': '69.77% (2019)',
#   'Share of the population using the Internet': '39.7% (2016)',
#   'Share of migrants among the population': '1.33% (2015)',
#   'International tourism: Number of arrivals': '959,000 (2016)',
#   'Beef and buffalo meat consumption per person': '19.78 (2013)',
#   'Beef production': '268,000 t (2018)',
#   'Share of land area used for agriculture': '34.81% (2015)',
#   'Forest area (% of land area)': '50.55% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '50.16% (2018)',
#   'Fossil-fuel subsidies per capita': '$61.11 (2015)',
#   'Death rates from air pollution': '53.9 (2017)',
#   'Direct disaster economic loss': '$11.59 million (2015)',
#   'Wine consumption per person': '0.03 litres (2014)'},
#  {'Country': 'Brazil',
#   'Consumption-based CO2 emissions': '513.05 million t (2017)',
#   'Annual greenhouse gas emissions': '2.99 million t (2012)',
#   'Population density': '24.03 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '211.05 million (2019)',
#   'GDP per capita': '$13,479 (2016)',
#   'Life expectancy': '75.9 years (2019)',
#   'Female employment-to-population ratio': '45.04 (2017)',
#   'Unemployment rate': '13.32% (2017)',
#   'Daily supply of calories': '3,248 kcal (2017)',
#   'Share of the population living in urban areas': '86.82% (2019)',
#   'Share of the population using the Internet': '60.87% (2016)',
#   'Share of migrants among the population': '0.34% (2015)',
#   'International tourism: Number of arrivals': '6.58 million (2016)',
#   'Beef and buffalo meat consumption per person': '39.25 (2013)',
#   'Beef production': '9.9 million t (2018)',
#   'Share of land area used for agriculture': '33.81% (2015)',
#   'Forest area (% of land area)': '59.05% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '42.17% (2018)',
#   'Fossil-fuel subsidies per capita': '$8.33 (2015)',
#   'Death rates from air pollution': '30.3 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.27 litres (2014)'},
#  {'Country': 'Barbados',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '1,540.62 t (2012)',
#   'Population density': '588.97 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '287,000 (2019)',
#   'GDP per capita': '$10,160 (2016)',
#   'Life expectancy': '79.2 years (2019)',
#   'Female employment-to-population ratio': '56.49 (2016)',
#   'Unemployment rate': '9.69% (2017)',
#   'Daily supply of calories': '2,896 kcal (2017)',
#   'Share of the population living in urban areas': '31.16% (2019)',
#   'Share of the population using the Internet': '79.55% (2016)',
#   'Share of migrants among the population': '12.13% (2015)',
#   'International tourism: Number of arrivals': '632,000 (2016)',
#   'Beef and buffalo meat consumption per person': '13.13 (2013)',
#   'Beef production': '176 t (2018)',
#   'Share of land area used for agriculture': '32.56% (2015)',
#   'Forest area (% of land area)': '14.65% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '2.53% (2018)',
#   'Fossil-fuel subsidies per capita': '$29.87 (2015)',
#   'Death rates from air pollution': '35.1 (2017)',
#   'Direct disaster economic loss': '$488,025 (2018)',
#   'Wine consumption per person': '0.83 litres (2014)'},
#  {'Country': 'Brunei',
#   'Consumption-based CO2 emissions': '8.05 million t (2017)',
#   'Annual greenhouse gas emissions': '14,828.97 t (2012)',
#   'Population density': '74.18 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '433,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '75.9 years (2019)',
#   'Female employment-to-population ratio': '50.87 (2017)',
#   'Unemployment rate': '7.08% (2017)',
#   'Daily supply of calories': '2,985 kcal (2013)',
#   'Share of the population living in urban areas': '77.94% (2019)',
#   'Share of the population using the Internet': '90% (2016)',
#   'Share of migrants among the population': '24.28% (2015)',
#   'International tourism: Number of arrivals': '219,000 (2016)',
#   'Beef and buffalo meat consumption per person': '12.15 (2013)',
#   'Beef production': '718 t (2018)',
#   'Share of land area used for agriculture': '2.73% (2015)',
#   'Forest area (% of land area)': '72.11% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '63.11% (2018)',
#   'Fossil-fuel subsidies per capita': '$329.47 (2015)',
#   'Death rates from air pollution': '20.3 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.05 litres (2011)'},
#  {'Country': 'Bhutan',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '3,296.96 t (2012)',
#   'Population density': '19.74 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '763,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '71.8 years (2019)',
#   'Female employment-to-population ratio': '54.18 (2015)',
#   'Unemployment rate': '2.43% (2017)',
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '41.61% (2019)',
#   'Share of the population using the Internet': '41.77% (2016)',
#   'Share of migrants among the population': '6.6% (2015)',
#   'International tourism: Number of arrivals': '210,000 (2016)',
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': '4,982 t (2018)',
#   'Share of land area used for agriculture': '13.79% (2015)',
#   'Forest area (% of land area)': '72.28% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '47.33% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '73.1 (2017)',
#   'Direct disaster economic loss': '$1.78 million (2018)',
#   'Wine consumption per person': '0.05 litres (2011)'},
#  {'Country': 'Botswana',
#   'Consumption-based CO2 emissions': '17.21 million t (2017)',
#   'Annual greenhouse gas emissions': '82,110.28 t (2012)',
#   'Population density': '3.63 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '2.3 million (2019)',
#   'GDP per capita': '$15,015 (2016)',
#   'Life expectancy': '69.6 years (2019)',
#   'Female employment-to-population ratio': '49.11 (2013)',
#   'Unemployment rate': '17.36% (2017)',
#   'Daily supply of calories': '2,340 kcal (2017)',
#   'Share of the population living in urban areas': '70.17% (2019)',
#   'Share of the population using the Internet': '39.36% (2016)',
#   'Share of migrants among the population': '7.1% (2015)',
#   'International tourism: Number of arrivals': '1.53 million (2015)',
#   'Beef and buffalo meat consumption per person': '7.85 (2013)',
#   'Beef production': '32,186 t (2018)',
#   'Share of land area used for agriculture': '45.88% (2015)',
#   'Forest area (% of land area)': '19.13% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '51.11% (2018)',
#   'Fossil-fuel subsidies per capita': '$48.97 (2015)',
#   'Death rates from air pollution': '69.8 (2017)',
#   'Direct disaster economic loss': '$113,058.48 (2018)',
#   'Wine consumption per person': '0.59 litres (2011)'},
#  {'Country': 'Central African Republic',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '515,134.08 t (2012)',
#   'Population density': '7.91 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '4.75 million (2019)',
#   'GDP per capita': '$619 (2016)',
#   'Life expectancy': '53.3 years (2019)',
#   'Female employment-to-population ratio': '59.13% (2017)',
#   'Unemployment rate': '5.95% (2017)',
#   'Daily supply of calories': '1,758 kcal (2017)',
#   'Share of the population living in urban areas': '41.77% (2019)',
#   'Share of the population using the Internet': '4% (2016)',
#   'Share of migrants among the population': '1.67% (2015)',
#   'International tourism: Number of arrivals': '120,500 (2015)',
#   'Beef and buffalo meat consumption per person': '11.92 (2013)',
#   'Beef production': '99,590 t (2018)',
#   'Share of land area used for agriculture': '8.15% (2015)',
#   'Forest area (% of land area)': '35.59% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '74.37% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '199.7 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.02 litres (2011)'},
#  {'Country': 'Canada',
#   'Consumption-based CO2 emissions': '591.65 million t (2017)',
#   'Annual greenhouse gas emissions': '1.03 million t (2012)',
#   'Population density': '3.98 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '37.41 million (2019)',
#   'GDP per capita': '$42,969 (2016)',
#   'Life expectancy': '82.4 years (2019)',
#   'Female employment-to-population ratio': '57.88 (2017)',
#   'Unemployment rate': '6.34% (2017)',
#   'Daily supply of calories': '3,492 kcal (2017)',
#   'Share of the population living in urban areas': '81.48% (2019)',
#   'Share of the population using the Internet': '91.16% (2016)',
#   'Share of migrants among the population': '21.8% (2015)',
#   'International tourism: Number of arrivals': '19.82 million (2016)',
#   'Beef and buffalo meat consumption per person': '30.25 (2013)',
#   'Beef production': '1.23 million t (2018)',
#   'Share of land area used for agriculture': '6.89% (2015)',
#   'Forest area (% of land area)': '38.17% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '26.47% (2018)',
#   'Fossil-fuel subsidies per capita': '$39.07 (2015)',
#   'Death rates from air pollution': '10.7 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '2 litres (2014)'},
#  {'Country': 'Switzerland',
#   'Consumption-based CO2 emissions': '121.32 million t (2017)',
#   'Annual greenhouse gas emissions': '54,108.1 t (2012)',
#   'Population density': '198.03 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '8.59 million (2019)',
#   'GDP per capita': '$61,844 (2016)',
#   'Life expectancy': '83.8 years (2019)',
#   'Female employment-to-population ratio': '59.44 (2017)',
#   'Unemployment rate': '4.8% (2017)',
#   'Daily supply of calories': '3,413 kcal (2017)',
#   'Share of the population living in urban areas': '73.85% (2019)',
#   'Share of the population using the Internet': '93.71% (2017)',
#   'Share of migrants among the population': '29.39% (2015)',
#   'International tourism: Number of arrivals': '9.21 million (2016)',
#   'Beef and buffalo meat consumption per person': '21.26 (2013)',
#   'Beef production': '147,970 t (2018)',
#   'Share of land area used for agriculture': '38.18% (2015)',
#   'Forest area (% of land area)': '31.73% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '35.23% (2018)',
#   'Fossil-fuel subsidies per capita': '$0 (2015)',
#   'Death rates from air pollution': '11.7 (2017)',
#   'Direct disaster economic loss': '$1.08 billion (2017)',
#   'Wine consumption per person': '4.57 litres (2014)'},
#  {'Country': 'Chile',
#   'Consumption-based CO2 emissions': '89.72 million t (2017)',
#   'Annual greenhouse gas emissions': '120,687.89 t (2012)',
#   'Population density': '24.69 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '18.95 million (2019)',
#   'GDP per capita': '$21,446 (2016)',
#   'Life expectancy': '80.2 years (2019)',
#   'Female employment-to-population ratio': '45.04 (2017)',
#   'Unemployment rate': '6.96% (2017)',
#   'Daily supply of calories': '3,011 kcal (2017)',
#   'Share of the population living in urban areas': '87.64% (2019)',
#   'Share of the population using the Internet': '82.33% (2017)',
#   'Share of migrants among the population': '2.62% (2015)',
#   'International tourism: Number of arrivals': '5.64 million (2016)',
#   'Beef and buffalo meat consumption per person': '23.86 (2013)',
#   'Beef production': '199,314 t (2018)',
#   'Share of land area used for agriculture': '21.23% (2015)',
#   'Forest area (% of land area)': '23.85% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '34.8% (2018)',
#   'Fossil-fuel subsidies per capita': '$0 (2015)',
#   'Death rates from air pollution': '24.3 (2017)',
#   'Direct disaster economic loss': '$134.81 million (2017)',
#   'Wine consumption per person': '2.65 litres (2014)'},
#  {'Country': 'China',
#   'Consumption-based CO2 emissions': '8.55 billion t (2017)',
#   'Annual greenhouse gas emissions': '12.45 million t (2012)',
#   'Population density': '147.53 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '1.43 billion (2019)',
#   'GDP per capita': '$12,320 (2016)',
#   'Life expectancy': '76.9 years (2019)',
#   'Female employment-to-population ratio': '58.88% (2017)',
#   'Unemployment rate': '4.68% (2017)',
#   'Daily supply of calories': '3,194 kcal (2017)',
#   'Share of the population living in urban areas': '60.31% (2019)',
#   'Share of the population using the Internet': '54.3% (2017)',
#   'Share of migrants among the population': '0.07% (2015)',
#   'International tourism: Number of arrivals': '59.27 million (2016)',
#   'Beef and buffalo meat consumption per person': '5.23 (2013)',
#   'Beef production': '6.46 million t (2018)',
#   'Share of land area used for agriculture': '56.22% (2015)',
#   'Forest area (% of land area)': '22.19% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '37.77% (2018)',
#   'Fossil-fuel subsidies per capita': '$0 (2015)',
#   'Death rates from air pollution': '72.7 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.17 litres (2014)'},
#  {'Country': "Cote d'Ivoire",
#   'Consumption-based CO2 emissions': '13.96 million t (2017)',
#   'Annual greenhouse gas emissions': '33,502.16 t (2012)',
#   'Population density': '75.32 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '25.72 million (2019)',
#   'GDP per capita': '$3,664 (2016)',
#   'Life expectancy': '57.8 years (2019)',
#   'Female employment-to-population ratio': '47.88 (2016)',
#   'Unemployment rate': '2.6% (2017)',
#   'Daily supply of calories': '2,730 kcal (2017)',
#   'Share of the population living in urban areas': '51.24% (2019)',
#   'Share of the population using the Internet': '43.84% (2017)',
#   'Share of migrants among the population': '9.58% (2015)',
#   'International tourism: Number of arrivals': '1.58 million (2016)',
#   'Beef and buffalo meat consumption per person': '1.7 (2013)',
#   'Beef production': '33,107 t (2018)',
#   'Share of land area used for agriculture': '64.78% (2015)',
#   'Forest area (% of land area)': '32.71% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '71.21% (2018)',
#   'Fossil-fuel subsidies per capita': '$42.37 (2015)',
# ...
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '1.63 litres (2014)'},
#  {'Country': 'Uzbekistan',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '177,223.75 t (2012)',
#   'Population density': '69.78 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '32.98 million (2019)',
#   'GDP per capita': '$9,726 (2016)',
#   'Life expectancy': '71.7 years (2019)',
#   'Female employment-to-population ratio': '50% (2017)',
#   'Unemployment rate': '7.18% (2017)',
#   'Daily supply of calories': '3,022 kcal (2017)',
#   'Share of the population living in urban areas': '50.43% (2019)',
#   'Share of the population using the Internet': '46.79% (2016)',
#   'Share of migrants among the population': '3.92% (2015)',
#   'International tourism: Number of arrivals': '1.97 million (2013)',
#   'Beef and buffalo meat consumption per person': '28.2 (2013)',
#   'Beef production': '922,364 t (2018)',
#   'Share of land area used for agriculture': '62.93% (2015)',
#   'Forest area (% of land area)': '7.57% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '15.47% (2018)',
#   'Fossil-fuel subsidies per capita': '$261.12 (2015)',
#   'Death rates from air pollution': '105.1 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.13 litres (2011)'},
#  {'Country': 'Vatican',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': None,
#   'Population density': '1,784.09 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '1,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '75.1 years (2019)',
#   'Female employment-to-population ratio': None,
#   'Unemployment rate': None,
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '100% (2019)',
#   'Share of the population using the Internet': None,
#   'Share of migrants among the population': None,
#   'International tourism: Number of arrivals': None,
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': None,
#   'Share of land area used for agriculture': None,
#   'Forest area (% of land area)': None,
#   'Share of important terrerstrial biodiversity sites that are protected': None,
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': None,
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': None},
#  {'Country': 'Saint Vincent and the Grenadines',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '319.22 t (2012)',
#   'Population density': '290.89 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '111,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '72.5 years (2019)',
#   'Female employment-to-population ratio': '47.1% (2017)',
#   'Unemployment rate': '18.28% (2017)',
#   'Daily supply of calories': '2,960 kcal (2017)',
#   'Share of the population living in urban areas': '52.61% (2019)',
#   'Share of the population using the Internet': '65.56% (2017)',
#   'Share of migrants among the population': '4.18% (2015)',
#   'International tourism: Number of arrivals': '79,000 (2016)',
#   'Beef and buffalo meat consumption per person': '9.37 (2013)',
#   'Beef production': '207 t (2018)',
#   'Share of land area used for agriculture': '25.64% (2015)',
#   'Forest area (% of land area)': '69.23% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '42.83% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '48.7 (2017)',
#   'Direct disaster economic loss': '$102,222 (2014)',
#   'Wine consumption per person': '0.23 litres (2014)'},
#  {'Country': 'Venezuela',
#   'Consumption-based CO2 emissions': '140.28 million t (2017)',
#   'Annual greenhouse gas emissions': '281,921.37 t (2012)',
#   'Population density': '34.39 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '28.52 million (2019)',
#   'GDP per capita': '$13,159 (2016)',
#   'Life expectancy': '72.1 years (2019)',
#   'Female employment-to-population ratio': '46.02 (2015)',
#   'Unemployment rate': '7.66% (2017)',
#   'Daily supply of calories': '2,247 kcal (2017)',
#   'Share of the population living in urban areas': '88.24% (2019)',
#   'Share of the population using the Internet': '60% (2016)',
#   'Share of migrants among the population': '4.51% (2015)',
#   'International tourism: Number of arrivals': '601,000 (2016)',
#   'Beef and buffalo meat consumption per person': '25.89 (2013)',
#   'Beef production': '442,290 t (2018)',
#   'Share of land area used for agriculture': '24.49% (2015)',
#   'Forest area (% of land area)': '52.93% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '66.46% (2018)',
#   'Fossil-fuel subsidies per capita': '$765.1 (2015)',
#   'Death rates from air pollution': '34.7 (2017)',
#   'Direct disaster economic loss': '$14.61 million (2015)',
#   'Wine consumption per person': '0.06 litres (2014)'},
#  {'Country': 'British Virgin Islands',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': None,
#   'Population density': '159.63 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '30,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '79.1 years (2019)',
#   'Female employment-to-population ratio': None,
#   'Unemployment rate': None,
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '48.12% (2019)',
#   'Share of the population using the Internet': '37.6% (2012)',
#   'Share of migrants among the population': '57.47% (2015)',
#   'International tourism: Number of arrivals': '408,000 (2016)',
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': '140 t (2018)',
#   'Share of land area used for agriculture': '46.67% (2015)',
#   'Forest area (% of land area)': '24.13% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '11.13% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': None,
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': None},
#  {'Country': 'United States Virgin Islands',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '61.49 t (2012)',
#   'Population density': '497.99 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '105,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '80.6 years (2019)',
#   'Female employment-to-population ratio': '52.75% (2017)',
#   'Unemployment rate': '7.13% (2017)',
#   'Daily supply of calories': None,
#   'Share of the population living in urban areas': '95.83% (2019)',
#   'Share of the population using the Internet': '59.61% (2016)',
#   'Share of migrants among the population': '53.36% (2015)',
#   'International tourism: Number of arrivals': '642,000 (2015)',
#   'Beef and buffalo meat consumption per person': None,
#   'Beef production': '505 t (2018)',
#   'Share of land area used for agriculture': '11.43% (2015)',
#   'Forest area (% of land area)': '50.29% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '46.31% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '29.7 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': None},
#  {'Country': 'Vietnam',
#   'Consumption-based CO2 emissions': '197.1 million t (2017)',
#   'Annual greenhouse gas emissions': '310,664.07 t (2012)',
#   'Population density': '286.34 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '96.46 million (2019)',
#   'GDP per capita': '$6,031 (2016)',
#   'Life expectancy': '75.4 years (2019)',
#   'Female employment-to-population ratio': '70.23 (2017)',
#   'Unemployment rate': '2.05% (2017)',
#   'Daily supply of calories': '2,938 kcal (2017)',
#   'Share of the population living in urban areas': '36.63% (2019)',
#   'Share of the population using the Internet': '46.5% (2016)',
#   'Share of migrants among the population': '0.08% (2015)',
#   'International tourism: Number of arrivals': '10.01 million (2016)',
#   'Beef and buffalo meat consumption per person': '7.44 (2013)',
#   'Beef production': '426,582 t (2018)',
#   'Share of land area used for agriculture': '37.77% (2015)',
#   'Forest area (% of land area)': '47.64% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '41.06% (2018)',
#   'Fossil-fuel subsidies per capita': '$12.18 (2015)',
#   'Death rates from air pollution': '60.3 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.02 litres (2014)'},
#  {'Country': 'Vanuatu',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '446.22 t (2012)',
#   'Population density': '21.45 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '300,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '70.5 years (2019)',
#   'Female employment-to-population ratio': '57.85% (2017)',
#   'Unemployment rate': '5.22% (2017)',
#   'Daily supply of calories': '2,623 kcal (2017)',
#   'Share of the population living in urban areas': '25.39% (2019)',
#   'Share of the population using the Internet': '24% (2016)',
#   'Share of migrants among the population': '1.2% (2015)',
#   'International tourism: Number of arrivals': '95,100 (2016)',
#   'Beef and buffalo meat consumption per person': '11.22 (2013)',
#   'Beef production': '3,151 t (2018)',
#   'Share of land area used for agriculture': '15.34% (2015)',
#   'Forest area (% of land area)': '36.1% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '6.39% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '139.7 (2017)',
#   'Direct disaster economic loss': '$233,700 (2014)',
#   'Wine consumption per person': '0.17 litres (2011)'},
#  {'Country': 'Samoa',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '356.09 t (2012)',
#   'Population density': '62.6 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '197,000 (2019)',
#   'GDP per capita': None,
#   'Life expectancy': '73.3 years (2019)',
#   'Female employment-to-population ratio': '21.89 (2014)',
#   'Unemployment rate': '8.21% (2017)',
#   'Daily supply of calories': '2,974 kcal (2017)',
#   'Share of the population living in urban areas': '18.06% (2019)',
#   'Share of the population using the Internet': '29.41% (2016)',
#   'Share of migrants among the population': '2.55% (2015)',
#   'International tourism: Number of arrivals': '134,000 (2016)',
#   'Beef and buffalo meat consumption per person': '10.38 (2013)',
#   'Beef production': '1,933 t (2018)',
#   'Share of land area used for agriculture': '12.37% (2015)',
#   'Forest area (% of land area)': '60.42% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '37.08% (2018)',
#   'Fossil-fuel subsidies per capita': None,
#   'Death rates from air pollution': '76.8 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.09 litres (2011)'},
#  {'Country': 'Yemen',
#   'Consumption-based CO2 emissions': None,
#   'Annual greenhouse gas emissions': '40,924.63 t (2012)',
#   'Population density': '66.38 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '29.16 million (2019)',
#   'GDP per capita': '$2,199 (2016)',
#   'Life expectancy': '66.1 years (2019)',
#   'Female employment-to-population ratio': '4.46 (2014)',
#   'Unemployment rate': '14.04% (2017)',
#   'Daily supply of calories': '2,063 kcal (2017)',
#   'Share of the population living in urban areas': '37.27% (2019)',
#   'Share of the population using the Internet': '24.58% (2016)',
#   'Share of migrants among the population': '1.28% (2015)',
#   'International tourism: Number of arrivals': '366,700 (2015)',
#   'Beef and buffalo meat consumption per person': '4.75 (2013)',
#   'Beef production': '117,617 t (2018)',
#   'Share of land area used for agriculture': '44.6% (2015)',
#   'Forest area (% of land area)': '1.04% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '31.08% (2018)',
#   'Fossil-fuel subsidies per capita': '$3.87 (2015)',
#   'Death rates from air pollution': '96.5 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0 litres (2013)'},
#  {'Country': 'South Africa',
#   'Consumption-based CO2 emissions': '340.87 million t (2017)',
#   'Annual greenhouse gas emissions': None,
#   'Population density': '42.38 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '58.56 million (2019)',
#   'GDP per capita': '$11,949 (2016)',
#   'Life expectancy': '64.1 years (2019)',
#   'Female employment-to-population ratio': '34.42 (2017)',
#   'Unemployment rate': '27.33% (2017)',
#   'Daily supply of calories': '2,994 kcal (2017)',
#   'Share of the population living in urban areas': '66.86% (2019)',
#   'Share of the population using the Internet': '54% (2016)',
#   'Share of migrants among the population': '5.77% (2015)',
#   'International tourism: Number of arrivals': '10.04 million (2016)',
#   'Beef and buffalo meat consumption per person': '18.03 (2013)',
#   'Beef production': '1 million t (2018)',
#   'Share of land area used for agriculture': '79.83% (2015)',
#   'Forest area (% of land area)': '7.62% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '30.7% (2018)',
#   'Fossil-fuel subsidies per capita': '$45.81 (2015)',
#   'Death rates from air pollution': '57.9 (2017)',
#   'Direct disaster economic loss': '$33.29 million (2016)',
#   'Wine consumption per person': '1.35 litres (2014)'},
#  {'Country': 'Zambia',
#   'Consumption-based CO2 emissions': '9.66 million t (2017)',
#   'Annual greenhouse gas emissions': '320,254.22 t (2012)',
#   'Population density': '20.15 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '17.86 million (2019)',
#   'GDP per capita': '$3,538 (2016)',
#   'Life expectancy': '63.9 years (2019)',
#   'Female employment-to-population ratio': '64.28% (2017)',
#   'Unemployment rate': '7.79% (2017)',
#   'Daily supply of calories': '2,013 kcal (2017)',
#   'Share of the population living in urban areas': '44.07% (2019)',
#   'Share of the population using the Internet': '25.51% (2016)',
#   'Share of migrants among the population': '0.79% (2015)',
#   'International tourism: Number of arrivals': '956,000 (2016)',
#   'Beef and buffalo meat consumption per person': '4.76 (2013)',
#   'Beef production': '187,197 t (2018)',
#   'Share of land area used for agriculture': '32.06% (2015)',
#   'Forest area (% of land area)': '65.42% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '48.36% (2018)',
#   'Fossil-fuel subsidies per capita': '$132.74 (2015)',
#   'Death rates from air pollution': '98.9 (2017)',
#   'Direct disaster economic loss': '$7.84 million (2016)',
#   'Wine consumption per person': '0.07 litres (2013)'},
#  {'Country': 'Zimbabwe',
#   'Consumption-based CO2 emissions': '12.53 million t (2017)',
#   'Annual greenhouse gas emissions': '72,057.8 t (2012)',
#   'Population density': '36.06 (2015)',
#   'Population (Gapminder & UN (1800 to 2019))': '14.64 million (2019)',
#   'GDP per capita': '$1,729 (2016)',
#   'Life expectancy': '61.5 years (2019)',
#   'Female employment-to-population ratio': '52.35 (2012)',
#   'Unemployment rate': '5.01% (2017)',
#   'Daily supply of calories': '2,173 kcal (2017)',
#   'Share of the population living in urban areas': '32.21% (2019)',
#   'Share of the population using the Internet': '23.12% (2016)',
#   'Share of migrants among the population': '2.56% (2015)',
#   'International tourism: Number of arrivals': '2.17 million (2016)',
#   'Beef and buffalo meat consumption per person': '7.37 (2013)',
#   'Beef production': '111,133 t (2018)',
#   'Share of land area used for agriculture': '41.88% (2015)',
#   'Forest area (% of land area)': '36.35% (2015)',
#   'Share of important terrerstrial biodiversity sites that are protected': '85.88% (2018)',
#   'Fossil-fuel subsidies per capita': '$201.48 (2015)',
#   'Death rates from air pollution': '125 (2017)',
#   'Direct disaster economic loss': None,
#   'Wine consumption per person': '0.05 litres (2014)'}]

# %% [markdown]
# ## Set up datafram

# %%
g_countries = pd.DataFrame(country_info_list)  #convert list of dict to df
g_countries.set_index('Country', inplace=True)

g_countries
# Out:
#              Consumption-based CO2 emissions Annual greenhouse gas emissions  \
# Country
# Aruba                                   None                            None
# Afghanistan                             None              18,168.86 t (2012)
# Angola                                  None              41,657.16 t (2012)
# Anguilla                                None                            None
# Albania                5.65 million t (2017)               8,898.64 t (2012)
# ...                                      ...                             ...
# Samoa                                   None                 356.09 t (2012)
# Yemen                                   None              40,924.63 t (2012)
# South Africa         340.87 million t (2017)                            None
# Zambia                 9.66 million t (2017)             320,254.22 t (2012)
# Zimbabwe              12.53 million t (2017)               72,057.8 t (2012)
#
#              Population density Population (Gapminder & UN (1800 to 2019))  \
# Country
# Aruba             619.64 (2015)                             106,000 (2019)
# Afghanistan        53.69 (2015)                       38.04 million (2019)
# Angola             17.33 (2015)                       31.82 million (2019)
# Anguilla          135.32 (2015)                              15,000 (2019)
# Albania           114.91 (2015)                        2.88 million (2019)
# ...                         ...                                        ...
# Samoa               62.6 (2015)                             197,000 (2019)
# Yemen              66.38 (2015)                       29.16 million (2019)
# South Africa       42.38 (2015)                       58.56 million (2019)
# Zambia             20.15 (2015)                       17.86 million (2019)
# Zimbabwe           36.06 (2015)                       14.64 million (2019)
#
#               GDP per capita    Life expectancy  \
# Country
# Aruba                   None  76.3 years (2019)
# Afghanistan    $1,929 (2016)  64.8 years (2019)
# Angola         $8,397 (2016)  61.1 years (2019)
# Anguilla                None  81.9 years (2019)
# Albania       $11,285 (2016)  78.6 years (2019)
# ...                      ...                ...
# Samoa                   None  73.3 years (2019)
# Yemen          $2,199 (2016)  66.1 years (2019)
# South Africa  $11,949 (2016)  64.1 years (2019)
# Zambia         $3,538 (2016)  63.9 years (2019)
# Zimbabwe       $1,729 (2016)  61.5 years (2019)
#
#              Female employment-to-population ratio Unemployment rate  \
# Country
# Aruba                                  53.4 (2011)              None
# Afghanistan                           15.48 (2012)      8.84% (2017)
# Angola                                69.13 (2011)      8.17% (2017)
# Anguilla                                      None              None
# Albania                               39.15 (2015)     13.87% (2017)
# ...                                            ...               ...
# Samoa                                 21.89 (2014)      8.21% (2017)
# Yemen                                  4.46 (2014)     14.04% (2017)
# South Africa                          34.42 (2017)     27.33% (2017)
# Zambia                               64.28% (2017)      7.79% (2017)
# Zimbabwe                              52.35 (2012)      5.01% (2017)
#
#              Daily supply of calories  \
# Country
# Aruba                            None
# Afghanistan         2,000 kcal (2017)
# Angola              2,270 kcal (2017)
# Anguilla                         None
# Albania             3,400 kcal (2017)
# ...                               ...
# Samoa               2,974 kcal (2017)
# Yemen               2,063 kcal (2017)
# South Africa        2,994 kcal (2017)
# Zambia              2,013 kcal (2017)
# Zimbabwe            2,173 kcal (2017)
#
#              Share of the population living in urban areas  ...  \
# Country                                                     ...
# Aruba                                        43.55% (2019)  ...
# Afghanistan                                  25.75% (2019)  ...
# Angola                                       66.18% (2019)  ...
# Anguilla                                       100% (2019)  ...
# Albania                                      61.23% (2019)  ...
# ...                                                    ...  ...
# Samoa                                        18.06% (2019)  ...
# Yemen                                        37.27% (2019)  ...
# South Africa                                 66.86% (2019)  ...
# Zambia                                       44.07% (2019)  ...
# Zimbabwe                                     32.21% (2019)  ...
#
#              International tourism: Number of arrivals  \
# Country
# Aruba                               1.1 million (2016)
# Afghanistan                                       None
# Angola                                  397,000 (2016)
# Anguilla                                          None
# Albania                            4.07 million (2016)
# ...                                                ...
# Samoa                                   134,000 (2016)
# Yemen                                   366,700 (2015)
# South Africa                      10.04 million (2016)
# Zambia                                  956,000 (2016)
# Zimbabwe                           2.17 million (2016)
#
#              Beef and buffalo meat consumption per person     Beef production  \
# Country
# Aruba                                                None                None
# Afghanistan                                   4.59 (2013)    129,691 t (2018)
# Angola                                        8.42 (2013)    104,761 t (2018)
# Anguilla                                             None                None
# Albania                                       22.5 (2013)     38,544 t (2018)
# ...                                                   ...                 ...
# Samoa                                        10.38 (2013)      1,933 t (2018)
# Yemen                                         4.75 (2013)    117,617 t (2018)
# South Africa                                 18.03 (2013)  1 million t (2018)
# Zambia                                        4.76 (2013)    187,197 t (2018)
# Zimbabwe                                      7.37 (2013)    111,133 t (2018)
#
#              Share of land area used for agriculture  \
# Country
# Aruba                                  11.11% (2015)
# Afghanistan                            58.07% (2015)
# Angola                                 47.48% (2015)
# Anguilla                                        None
# Albania                                42.86% (2015)
# ...                                              ...
# Samoa                                  12.37% (2015)
# Yemen                                   44.6% (2015)
# South Africa                           79.83% (2015)
# Zambia                                 32.06% (2015)
# Zimbabwe                               41.88% (2015)
#
#              Forest area (% of land area)  \
# Country
# Aruba                        2.33% (2015)
# Afghanistan                  2.07% (2015)
# Angola                      46.41% (2015)
# Anguilla                             None
# Albania                     28.16% (2015)
# ...                                   ...
# Samoa                       60.42% (2015)
# Yemen                        1.04% (2015)
# South Africa                 7.62% (2015)
# Zambia                      65.42% (2015)
# Zimbabwe                    36.35% (2015)
#
#              Share of important terrerstrial biodiversity sites that are protected  \
# Country
# Aruba                                              31.9% (2018)
# Afghanistan                                        6.14% (2018)
# Angola                                            28.37% (2018)
# Anguilla                                           0.15% (2018)
# Albania                                           76.11% (2018)
# ...                                                         ...
# Samoa                                             37.08% (2018)
# Yemen                                             31.08% (2018)
# South Africa                                       30.7% (2018)
# Zambia                                            48.36% (2018)
# Zimbabwe                                          85.88% (2018)
#
#              Fossil-fuel subsidies per capita Death rates from air pollution  \
# Country
# Aruba                                    None                           None
# Afghanistan                      $0.83 (2015)                   183.9 (2017)
# Angola                          $38.37 (2015)                    95.2 (2017)
# Anguilla                                 None                           None
# Albania                         $21.74 (2015)                    40.5 (2017)
# ...                                       ...                            ...
# Samoa                                    None                    76.8 (2017)
# Yemen                            $3.87 (2015)                    96.5 (2017)
# South Africa                    $45.81 (2015)                    57.9 (2017)
# Zambia                         $132.74 (2015)                    98.9 (2017)
# Zimbabwe                       $201.48 (2015)                     125 (2017)
#
#              Direct disaster economic loss Wine consumption per person
# Country
# Aruba                                 None                        None
# Afghanistan          $52.18 million (2017)             0 litres (2013)
# Angola               $69.24 million (2018)          1.32 litres (2014)
# Anguilla                              None                        None
# Albania               $5.33 million (2018)          1.14 litres (2014)
# ...                                    ...                         ...
# Samoa                                 None          0.09 litres (2011)
# Yemen                                 None             0 litres (2013)
# South Africa         $33.29 million (2016)          1.35 litres (2014)
# Zambia                $7.84 million (2016)          0.07 litres (2013)
# Zimbabwe                              None          0.05 litres (2014)
#
# [228 rows x 22 columns]

# %% [markdown]
# ## Place into pickle

# %%
filename = 'country_pic'
outfile = open(filename,'wb')

# %%
pickle.dump(g_countries,outfile)
outfile.close()
